# %%
import os
from PIL import Image

yourpath = 'T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\\tiles\\useful\\tif'
for root, dirs, files in os.walk(yourpath, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        if os.path.splitext(os.path.join(root, name))[1].lower() == ".tif":
            if os.path.isfile(os.path.splitext(os.path.join(root, name))[0] + ".jpg"):
                print ("A jpeg file already exists for %s" % name)
            # If a jpeg is *NOT* present, create one from the tiff.
            else:
                outfile = os.path.splitext(os.path.join(root, name))[0] + ".jpg"
                try:
                    im = Image.open(os.path.join(root, name))
                    print ("Generating jpeg for %s" % name)
                    im.thumbnail(im.size)
                    im.save(outfile, "JPEG", quality=100)
                except Exception:
                    print ('ERROR')
# Out:
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_148428.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_148428.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_148927.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_148927.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_150926.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_150926.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_181932.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_181932.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_181933.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_181933.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_182433.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_182433.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_195423.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_195423.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_202956.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_202956.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_204396.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_204396.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_214458.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_214458.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_215420.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_215420.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_215421.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_215421.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_215920.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_215920.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_216391.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_216391.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_216392.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_216392.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_228940.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_228940.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_228941.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_228941.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_229441.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_229441.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_229442.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_229442.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_229939.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_229939.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_230439.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_230439.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_230440.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_230440.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_234842.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_234842.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_234843.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_234843.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_235342.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_235342.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_235343.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_235343.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_235344.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_235344.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_235843.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_235843.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_237845.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_237845.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_243355.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_243355.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_243855.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_243855.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_86309.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_86309.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_86310.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_86310.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_86809.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_86809.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_94024.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_94024.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_94025.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_94025.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_94524.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_94524.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_96035.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_96035.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_96533.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_96533.tif
# T:\Python projects\TU-InstituteofTransportSciences\Tiles\HugeTile46\tiles\useful\tif\DOP_CRS3035RES50000mN2800000E4750000_20220128_96534.tif
# Generating jpeg for DOP_CRS3035RES50000mN2800000E4750000_20220128_96534.tif
